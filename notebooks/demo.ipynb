# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / 'src'))

# %%
import pandas as pd
import main

# %%
# %run ../src/main.py
# Out:
# === Financial Statement Analyser (Batch Mode) ===
#
# Processing 3 ticker(s)...
#
# Analysing AAPL...
#   [+] Success: AAPL report saved to D:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\AAPL_report
# Analysing MSFT...
#   [+] Success: MSFT report saved to D:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\MSFT_report
# Analysing LINUX...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: LINUX"}}}
#   [!] No data found for LINUX. Skipping...
#
# Generating Sector Comparison...
#   [>>>] Sector Comparison saved to: d:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\Sector_Comparison.csv
#
# === Batch Processing Complete ===

# %%
s = 'AAPL'
keys = ['main_report']
dfs = {}
for k in keys:
    dfs[k] = pd.read_csv(f'../outputs/{s}_report/{k}.csv')

# %%
dfs[keys[0]].head(10)
# Out:
#          Date  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0  2024-12-31       124300.0     36330.0      344085.0           277327.0
# 1  2025-03-31        95359.0     24780.0      331233.0           264437.0
# 2  2025-06-30        94036.0     23434.0      331495.0           265665.0
# 3  2025-09-30       102466.0     27466.0      359241.0           285508.0
# 4  2025-12-31       143756.0     42097.0      379297.0           291107.0
#
#    Stockholders Equity  Current Assets  Current Liabilities  Free Cash Flow  \
# 0              66758.0        133240.0             144365.0         26995.0
# 1              66796.0        118674.0             144571.0         20881.0
# 2              65830.0        122491.0             141120.0         24405.0
# 3              73733.0        147957.0             165631.0         26486.0
# 4              88190.0        158104.0             162367.0         51552.0
#
# ...

# %%
compare_df = pd.read_csv(f'../outputs/Sector_Comparison.csv')
compare_df
# Out:
#   Ticker  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   AAPL       143756.0     42097.0      379297.0           291107.0
# 1   MSFT        81273.0     38458.0      665302.0           274427.0
#
#    Stockholders Equity  Current Assets  Current Liabilities  Free Cash Flow  \
# 0              88190.0        158104.0             162367.0         51552.0
# 1             390875.0        180190.0             130005.0          5882.0
#
#       Inventory   Receivables  Gross Profit  Rev Growth (%)  Net Margin (%)  \
# 0  5.875000e+09  7.032000e+10  6.923100e+10           40.30           29.28
# 1  1.059000e+09  5.653500e+10  5.529500e+10            4.63           47.32
#
#    Gross Margin (%)  Cash Cycle (Days)  Current Ratio  Debt Ratio
# 0             48.16             193.46           0.97        0.77
# 1             68.04             258.66           1.39        0.41
