# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / 'src'))

# %%
import pandas as pd
import main

# %%
# %run ../src/main.py
# Out:
# === Financial Statement Generator ===
#
# --- Initialising Analysis for AAPL ---
# SUCCESS: Report generated in British English.
# LOCATION: D:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\AAPL_report

# %%
s = 'AAPL'
keys = ['main_report']
dfs = {}
for k in keys:
    dfs[k] = pd.read_csv(f'../outputs/{s}_report/{k}.csv')

# %%
dfs[keys[0]].head(10)
# Out:
#          Date  Total Revenue  Gross Profit  Net Income  Total Assets  \
# 0  2024-12-31       124300.0       58275.0     36330.0      344085.0
# 1  2025-03-31        95359.0       44867.0     24780.0      331233.0
# 2  2025-06-30        94036.0       43718.0     23434.0      331495.0
# 3  2025-09-30       102466.0       48341.0     27466.0      359241.0
# 4  2025-12-31       143756.0       69231.0     42097.0      379297.0
#
#    Inventory   Receivables  Accounts Payable  Current Assets  \
# 0     6911.0  5.930600e+10      6.191000e+10    1.332400e+11
# 1     6269.0  4.979800e+10      5.412600e+10    1.186740e+11
# 2     5925.0  4.683500e+10      5.037400e+10    1.224910e+11
# 3     5718.0  7.295700e+10      6.986000e+10    1.479570e+11
# 4     5875.0  7.032000e+10      7.058700e+10    1.581040e+11
#
#    Current Liabilities  Free Cash Flow  Gross Margin (%)  Net Margin (%)  \
# 0         1.443650e+11         26995.0             46.88           29.23
# 1         1.445710e+11         20881.0             47.05           25.99
# 2         1.411200e+11         24405.0             46.49           24.92
# 3         1.656310e+11         26486.0             47.18           26.80
# 4         1.623670e+11         51552.0             48.16           29.28
#
#    Days Inventory  Days Sales Out  Cash Conversion Cycle (Days)
# 0           20.29          174.15                        194.44
# 1           24.00          190.61                        214.60
# 2           23.00          181.79                        204.79
# 3           20.37          259.88                        280.25
# 4           14.92          178.54                        193.46
