# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / 'src'))

# %%
import pandas as pd
from main import run_pipeline

# %%
s = 'AAPL'
run_pipeline(s)
# Out:
# Processing AAPL...
# Success! Files saved to: ../outputs/AAPL_report

# %%
keys = ['balance_sheet', 'cash_flow', 'income_statement', 'insights']
bs_, cf_, is_, in_ = tuple(keys)
dfs = {}
for k in keys:
    dfs[k] = pd.read_csv(f'../outputs/{s}_report/{k}.csv')

# %%
dfs[bs_].head()
# Out:
#          Date  Treasury Shares Number  Ordinary Shares Number  Share Issued  \
# 0  2025-09-30                     NaN            1.477326e+10  1.477326e+10
# 1  2024-09-30                     NaN            1.511679e+10  1.511679e+10
# 2  2023-09-30                     0.0            1.555006e+10  1.555006e+10
# 3  2022-09-30                     NaN            1.594342e+10  1.594342e+10
# 4  2021-09-30                     NaN                     NaN           NaN
#
#        Net Debt    Total Debt  Tangible Book Value  Invested Capital  \
# 0  6.272300e+10  9.865700e+10         7.373300e+10      1.723900e+11
# 1  7.668600e+10  1.066290e+11         5.695000e+10      1.635790e+11
# 2  8.112300e+10  1.110880e+11         6.214600e+10      1.732340e+11
# 3  9.642300e+10  1.324800e+11         5.067200e+10      1.707410e+11
# 4           NaN           NaN                  NaN               NaN
#
#    Working Capital  Net Tangible Assets  ...  Other Current Assets  \
# ...

# %%
dfs[cf_].head()
# Out:
#          Date  Free Cash Flow  Repurchase Of Capital Stock  Repayment Of Debt  \
# 0  2025-09-30    9.876700e+10                -9.071100e+10      -1.093200e+10
# 1  2024-09-30    1.088070e+11                -9.494900e+10      -9.958000e+09
# 2  2023-09-30    9.958400e+10                -7.755000e+10      -1.115100e+10
# 3  2022-09-30    1.114430e+11                -8.940200e+10      -9.543000e+09
# 4  2021-09-30             NaN                          NaN                NaN
#
#    Issuance Of Debt  Issuance Of Capital Stock  Capital Expenditure  \
# 0      4.481000e+09                        NaN        -1.271500e+10
# 1      0.000000e+00                        NaN        -9.447000e+09
# 2      5.228000e+09                        NaN        -1.095900e+10
# 3      5.465000e+09                        NaN        -1.070800e+10
# 4               NaN               1.105000e+09                  NaN
#
#    Interest Paid Supplemental Data  Income Tax Paid Supplemental Data  \
# ...

# %%
dfs[is_].head()
# Out:
#          Date  Tax Effect Of Unusual Items  Tax Rate For Calcs  \
# 0  2025-09-30                          0.0               0.156
# 1  2024-09-30                          0.0               0.241
# 2  2023-09-30                          0.0               0.147
# 3  2022-09-30                          0.0               0.162
# 4  2021-09-30                          NaN                 NaN
#
#    Normalized EBITDA  \
# 0       1.447480e+11
# 1       1.346610e+11
# 2       1.258200e+11
# 3       1.305410e+11
# 4                NaN
#
#    Net Income From Continuing Operation Net Minority Interest  \
# 0                                       1.120100e+11
# 1                                       9.373600e+10
# 2                                       9.699500e+10
# 3                                       9.980300e+10
# 4                                                NaN
#
#    Reconciled Depreciation  Reconciled Cost Of Revenue        EBITDA  \
# ...

# %%
dfs[in_].head()
# Out:
#          Date    Net Income  Total Revenue  Profit Margin
# 0  2025-09-30  1.120100e+11   4.161610e+11       0.269151
# 1  2024-09-30  9.373600e+10   3.910350e+11       0.239713
# 2  2023-09-30  9.699500e+10   3.832850e+11       0.253062
# 3  2022-09-30  9.980300e+10   3.943280e+11       0.253096
# 4  2021-09-30           NaN            NaN            NaN
