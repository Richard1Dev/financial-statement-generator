# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / 'src'))

# %%
import pandas as pd
import main

# %%
# %run ../src/main.py
# Out:
# === Financial Statement Generator ===
#
# --- Initialising Analysis for AAPL ---
# SUCCESS: Report generated in British English.
# LOCATION: D:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\AAPL_report

# %%
s = 'AAPL'
keys = ['main_report']
dfs = {}
for k in keys:
    dfs[k] = pd.read_csv(f'../outputs/{s}_report/{k}.csv')

# %%
dfs[keys[0]].head(10)
# Out:
#          Date  Total Revenue  Gross Profit  Net Income  Total Assets  \
# 0  2024-12-31       124300.0       58275.0     36330.0      344085.0
# 1  2025-03-31        95359.0       44867.0     24780.0      331233.0
# 2  2025-06-30        94036.0       43718.0     23434.0      331495.0
# 3  2025-09-30       102466.0       48341.0     27466.0      359241.0
# 4  2025-12-31       143756.0       69231.0     42097.0      379297.0
#
#    Total Liabilities Net Minority Interest  Stockholders Equity  Inventory  \
# 0                                 277327.0              66758.0     6911.0
# 1                                 264437.0              66796.0     6269.0
# 2                                 265665.0              65830.0     5925.0
# 3                                 285508.0              73733.0     5718.0
# 4                                 291107.0              88190.0     5875.0
#
#     Receivables  Current Assets  Current Liabilities  Free Cash Flow  \
# 0  5.930600e+10        133240.0             144365.0         26995.0
# 1  4.979800e+10        118674.0             144571.0         20881.0
# 2  4.683500e+10        122491.0             141120.0         24405.0
# 3  7.295700e+10        147957.0             165631.0         26486.0
# 4  7.032000e+10        158104.0             162367.0         51552.0
#
#    Revenue Growth (%)  Net Margin (%)  Current Ratio
# 0                 NaN           29.23           0.92
# 1              -23.28           25.99           0.82
# 2               -1.39           24.92           0.87
# 3                8.96           26.80           0.89
# 4               40.30           29.28           0.97
