# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / 'src'))

# %%
import pandas as pd
import main

# %%
# %run main
# Out:
# Processing AAPL...
# Success! Files saved to: D:\Users\Work\Documents\Github Repo\2026\financial-statement-generator\outputs\AAPL_report

# %%
keys = ['balance_sheet', 'cash_flow', 'income_statement', 'insights']
keys = ['key_ratios','summary_statement_millions']
keys = ['main_report']
dfs = {}
for k in keys:
    dfs[k] = pd.read_csv(f'../outputs/{s}_report/{k}.csv')

# %%
dfs[keys[0]].head(10)
# Out:
#          Date  Total Revenue  Gross Profit  Net Income  Total Assets  \
# 0  2024-12-31       124300.0       58275.0     36330.0      344085.0
# 1  2025-03-31        95359.0       44867.0     24780.0      331233.0
# 2  2025-06-30        94036.0       43718.0     23434.0      331495.0
# 3  2025-09-30       102466.0       48341.0     27466.0      359241.0
# 4  2025-12-31       143756.0       69231.0     42097.0      379297.0
#
#    Total Debt  Current Assets  Current Liabilities  Free Cash Flow  \
# 0     96799.0        133240.0             144365.0         26995.0
# 1     98186.0        118674.0             144571.0         20881.0
# 2    101698.0        122491.0             141120.0         24405.0
# 3     98657.0        147957.0             165631.0         26486.0
# 4     90509.0        158104.0             162367.0         51552.0
#
#    Revenue Growth (%)  Net Margin (%)  Current Ratio
# 0                 NaN       29.227675       0.922938
# 1          -23.283186       25.986011       0.820870
# 2           -1.387389       24.920243       0.867992
# 3            8.964652       26.804989       0.893293
# 4           40.296293       29.283647       0.973745
